# %%
import pandas as pd
# import matplotlib as pd

import matplotlib.pyplot as plt

# %%
customers_data=pd.read_csv('Mall_Customers segmentation data.csv')
customers_data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
customers_data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print(f'the mean for Age is:{customers_data['Age'].mean()} ')
print(f'the median for AGE is:{customers_data['Age'].median()}')
print(f'\nthe quartiles of the Age is:{customers_data['Age'].quantile([0.25,0.5,0.75])}')

print(f'\n\n\nthe mean for the spending_score is:{customers_data['Spending Score (1-100)'].mean()}')
print(f'the median for the Spending_score is:{customers_data['Spending Score (1-100)'].median()}')
print(f'\nthe quartiles of the Spending_scole is:{customers_data['Spending Score (1-100)'].quantile([0.25,0.5,0.75])}')
# Out:
# the mean for Age is:38.85
# the median for AGE is:36.0
#
# the quartiles of the Age is:0.25    28.75
# 0.50    36.00
# 0.75    49.00
# Name: Age, dtype: float64
#
#
#
# the mean for the spending_score is:50.2
# the median for the Spending_score is:50.0
#
# the quartiles of the Spending_scole is:0.25    34.75
# 0.50    50.00
# 0.75    73.00
# Name: Spending Score (1-100), dtype: float64

# %%
x=list(customers_data['Age'])
y=list(customers_data['Spending Score (1-100)'])
plt.scatter(x,y,color='purple')
plt.xlabel("---Age---")
plt.subplot()
plt.grid(True)
plt.title("Age against Spending Score%")
plt.ylabel("--- Spending Score %% ---")
plt.show()

# %%
x=list(customers_data['Age'])
plt.hist(x,bins=10)
plt.xlabel("<<Age>>")
plt.ylabel("<<Frequency>>")
plt.title("AGE AGAINST FREQUENCY")
alpha=0.7
plt.show()

# %%
store_data=pd.read_csv("superstore_final_dataset.csv.csv")
store_data.head(5)
store_data.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code      float64
# Region            object
# Product_ID        object
# Category          object
# Sub_Category      object
# Product_Name      object
# Sales            float64
# dtype: object

# %%
store_data.describe()
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# store_data['Order_Date'] = pd.to_datetime(store_data['Order_Date'], errors='coerce')
store_data['Order_Date'] = store_data['Order_Date'].astype(str).str.extract(r'\/(\d+)\/')
store_data=store_data.head(20)
store_data = store_data.dropna(subset=['Order_Date'])
store_data['Order_Date']
# Out:
# 0     11
# 1     11
# 2     06
# 3     10
# 4     10
# 5     06
# 6     06
# 7     06
# 8     06
# 9     06
# 10    06
# 11    06
# 12    04
# 13    12
# 14    11
# 15    11
# 16    11
# 17    05
# 18    08
# 19    08
# Name: Order_Date, dtype: object

# %%
# store_data['Order_Date'] = pd.to_numeric(store_data['Order_Date'])
grouped_data = store_data.groupby('Sales')['Order_Date'].sum().reset_index()
grouped_data.sum()
# Out:
# Sales                                        7141.0715
# Order_Date    1106080604061006051106081112111106061006
# dtype: object

# %%
plt.plot(grouped_data['Order_Date'], grouped_data['Sales'], marker='x', linestyle='--')

# Labels and title
plt.xlabel('Order Date')
plt.ylabel('Total Sales')
plt.title('Sales Trend Over Time')

# Improve x-axis labels
plt.xticks(rotation=90)
plt.show()

# %%
grouped_data = store_data.groupby('Sales')['Order_Date'].sum().reset_index().sort_values(by='Order_Date')
# grouped_data=grouped_data.head(10000)
fig, ax = plt.subplots()

# plt.bar(grouped_data['Order_Date'], grouped_data['Sales'])
ax.bar(grouped_data['Order_Date'], grouped_data['Sales'], color='skyblue')
# Labels and title
plt.xlabel('Order Date')
plt.ylabel('Total Sales')
plt.title('Sales Trend Over Time')

# Improve x-axis labels
plt.xticks(rotation=90)
plt.show()

# %%
    
    # Plot pie chart with better styling
plt.pie(store_data['Sales'], labels=store_data['Region'], autopct='%1.1f%%',
           colors=['skyblue', 'lightcoral', 'gold', 'lightgreen'], 
          )  # Adds clear edge to slices

    # Add title with better formatting
plt.title("Sales Distribution by Region", fontsize=14, fontweight='bold')

    # Show legend with improved location
plt.legend(title="Regions", loc="upper right", bbox_to_anchor=(1.2, 1))

    # Show the pie chart
plt.show()

# %%
housing_data=pd.read_csv("housing.csv")
housing_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
historical_data=pd.read_csv("historical weather data.csv")
historical_data['dt_iso'] = pd.to_datetime(historical_data['dt_iso'], errors='coerce')
historical_data['dt_iso']
# Out:
# 0        1990-01-01 00:00:00
# 1        1990-01-01 01:00:00
# 2        1990-01-01 02:00:00
# 3        1990-01-01 03:00:00
# 4        1990-01-01 04:00:00
#                  ...
# 264919   2020-01-07 19:00:00
# 264920   2020-01-07 20:00:00
# 264921   2020-01-07 21:00:00
# 264922   2020-01-07 22:00:00
# 264923   2020-01-07 23:00:00
# Name: dt_iso, Length: 264924, dtype: datetime64[ns]

# %%
averages = []
columns = []

for col in historical_data.columns:
    if pd.api.types.is_numeric_dtype(historical_data[col]):  # Ensure column is numeric
        averages.append(historical_data[col].mean())
        columns.append(col)

# Ensure we have enough colors for the number of columns
colors = ['red', 'blue', 'green', 'pink', 'darkblue', 'purple', 'skyblue', 'black', 'brown']
colors = colors[:len(columns)]  # Adjust colors list if needed

plt.bar(columns, averages)  
plt.xlabel("Weather Metrics")
plt.ylabel("Averages")
plt.title("Temperature Averages Against Weather Metrics")
plt.grid(True)
plt.xticks(rotation=80)  # Rotate labels for better readability
plt.show()
